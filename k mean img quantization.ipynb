# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def img_reconstruct(img_path, K=10):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    Z = img.reshape((-1,3))
    Z = np.float32(Z)
    
    # define criteria, number of clusters(K) and apply kmeans()
    criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 9, 5.0)

    ret,label,center=cv2.kmeans(Z,K,None,criteria,10,cv2.KMEANS_RANDOM_CENTERS)

    # Now convert back into uint8, and make original image
    center = np.uint8(center)
    res = center[label.flatten()]
    res2 = res.reshape((img.shape))

    plt.figure(figsize=(18, 18))
    plt.imshow(res2)
    
    return res2

# %%
result = img_reconstruct('img/blue-2705642_640.jpg', 7)

# %%
plt.imsave('bb1.png', result)

# %%
cv2.imwrite('bb1_cv.jpg', result)#blue output #high size
# Out:
# True
